# %% [markdown]
# ## Practical 1 (Python Primer)

# %% [markdown]
# #### 1. Given the following dictionary:

# %% [markdown]
# student_grades = {'Adam':'CR', 'Leo':'HD', 'Max':'D', 'Nicole':'CR', 'Oscar':'P'}
#
# print all key-value pairs:
# ('Adam', 'CR') <br>
# ('Leo', 'HD') <br>
# ('Max', 'D')  <br>
# ('Nicole', 'CR')  <br>
# ('Oscar', 'P')

# %% [markdown]
# #### Solution:

# %% [markdown]
# #### 2. Given the same dictionary as above, print all keys.

# %% [markdown]
# #### Solution:

# %% [markdown]
# #### 3. Given the same dictionary as above, print all values.

# %% [markdown]
# #### 4. Write a Python program that prints the current date and time in the same format as the following example:

# %% [markdown]
# 2020-08-11 10:38:48. <br>
# Note that you have to import the datetime module and use the instance method: date.strftime(format) for this purpose. <br>
# Check the Python documentation for details.

# %% [markdown]
# #### Solution:

# %% [markdown]
# #### 5. Given a list of seven fruits:

# %% [markdown]
# ['Apple', 'Banana', 'Fig', 'Pear', 'Plum', 'Peach', 'Raspberry'] <br>
# write Python code that always removes the first fruit, the fifth fruit, and the sixth fruit from such a list and returns the following list: <br>
# ['Banana', 'Fig', 'Pear', 'Raspberry'].

# %% [markdown]
# Note that for the following list: <br> ['Banana', 'Apple', 'Pear', 'Plum', 'Peach', 'Fig', 'Raspberry'],
# the result should look as follows: <br> ['Apple', 'Pear', 'Plum', 'Raspberry'].

# %% [markdown]
# #### Solution:

# %% [markdown]
# #### 6. Open a new editor window and write a Python program that writes the following text into a text file:

# %% [markdown]
# Hello COMP SCI 7327 <br> This is our new text file<br> and this is another line. <br>Why? Because this is a basic task.

# %% [markdown]
# #### Solution:

# %% [markdown]
# Now add code that reads this file again and check.

# %% [markdown]
# #### 7. Write a Python function that returns the following outputs using the list `num = [1, 12, 19, 20, 12, 91, 10, 9, 1]`.
#
# 1. sum of all the list items
# 2. aveage of all the list items
# 3. minumum value in the list
# 4. maximum value in the list
# 5. the base-2 logarithm of all the list items (return type should be a list)
# 6. odd numbers in the list (return type should be a list)

# %% [markdown]
# #### 8. What are the similarities and differences of the following data types in Python?
# 1. List
# 2. Dictionary
# 3. Tuple
# 4. Set

# %% [markdown]
# The following table compares different properties of the 4 built-in data types in Python used to store collections of data, which are lists, dictioinaries, tuples and sets. If you are unsure or unclear of any of the properties mentioned below, please revisit the course content.
#
# ![types.png](data:image/png;base64,...)
#
# - *Changeable (also known as mutable) means that we can change, add, and remove elements in a data type after it has been created.*
#
# - *Indexed means the first element has index 0 and so on.*
#
# - *Ordered means that the elements in a given data type have a defined order, and that order will not change.*

# %% [markdown]
# #### 9. Write a Python program using sklearn library to do the following tasks.
# 1. Download the Iris dataset from sklearn
# 2. How many features are there in the Iris dataset?
# 3. How many data points are there in the Iris dataset?
# 4. How many targets are there in the Iris dataset?
# 5. Split the Iris dataset in train (70%) and test (30%) splits using `train_test_split` in sklearn. Why do we need to state `random_state` parameter when splitting a dataset int0 train and test splits?
# 6. Print the sizes of training and testing splits.

# %% [markdown]
# #### 10. Use Pandas library
# 1. Convert the iris dataset to a pandas frame
# 2. Display a summary of the dataset
# 3. Inspect basic statistics of the dataset
# 4. Print the number of samples in each class
# 5. Display the lable distribution
# 6. Display the histogram of all the features
